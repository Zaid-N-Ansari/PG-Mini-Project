# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/Zaid-N-Ansari/PG-Mini-Project/refs/heads/main/Data/GroceryTDS.csv?token=GHSAT0AAAAAADCE7OAHWN5ABAWJDZE2TTPA2AMNSYQ', header=None)
df = pd.read_csv('../Data/GroceryTDS.csv', header=None)

# %%
# df = df.drop(columns=['Unnamed: 0'])

# %%
# df.columns = df.columns.str.replace(' ', '_')

# %%
print(df.__len__())
df.sample(10)
# Out:
# 7501
#           0                  1                2                 3   \
# 3790  3789.0  whole wheat pasta  frozen smoothie          brownies
# 6798  6797.0            cookies              NaN               NaN
# 5012  5011.0            burgers           shrimp          tomatoes
# 4415  4414.0         energy bar       candy bars               NaN
# 2696  2695.0           sandwich              NaN               NaN
# 6362  6361.0            burgers       energy bar  whole wheat rice
# 2662  2661.0  frozen vegetables   vegetables mix              eggs
# 3129  3128.0               gums              NaN               NaN
# 5916  5915.0            cookies              NaN               NaN
# 2600  2599.0           tomatoes    mineral water           avocado
#
#                  4               5         6                 7            8   \
# 3790   energy drink             NaN       NaN               NaN          NaN
# ...

# %%
te = TransactionEncoder()
te_array = te.fit(df).transform(df)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 te = TransactionEncoder()
# ----> 2 te_array = te.fit(df).transform(df)
#       3 df_encoded = pd.DataFrame(te_array, columns=te.columns_)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlxtend\preprocessing\transactionencoder.py:58, in TransactionEncoder.fit(self, X)
#      56 unique_items = set()
#      57 for transaction in X:
# ---> 58     for item in transaction:
#      59         unique_items.add(item)
#      60 self.columns_ = sorted(unique_items)
#
# TypeError: 'int' object is not iterable
